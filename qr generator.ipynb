# %%
pip install qrcode
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import qrcode

# %%
aqsa="www.linkedin.com/in/aqsamahaksaifi"
image=qrcode.make(aqsa)

# %%
image

# %%
a="https://datacraftai.blogspot.com/"
image=qrcode.make(a)
image

# %%
linkedin="https://github.com/aqsamahak"
qr=qrcode.make(linkedin)
qr
